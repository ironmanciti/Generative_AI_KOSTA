# %%
## 영상용 api 키, 하고 바로 삭제하기
import requests
import re
from dotenv import load_dotenv
import os
import xml.etree.ElementTree as ET
from datetime import datetime
from pprint import pprint
from youtube_transcript_api import YouTubeTranscriptApi

load_dotenv()
YOUTUBE_API_KEY = os.getenv("YOUTUBE_API_KEY")
YOUTUBE_API_URL = 'https://www.googleapis.com/youtube/v3'

# %%
def get_youtube_transcript(url: str) -> str:
    """ 유튜브 영상 URL에 대한 자막을 가져옵니다."""
    
    # 1. 유튜브 URL에서 비디오 ID를 추출합니다.
    video_id_match = re.search(r"(?:v=|\/)([0-9A-Za-z_-]{11}).*", url)
    if not video_id_match:
        raise ValueError("유효하지 않은 YouTube URL이 제공되었습니다")
    video_id = video_id_match.group(1)
    
    languages = ["ko", "en"]
    # 2. youtube_transcript_api를 사용하여 자막을 가져옵니다.
    try:
        transcript_list = YouTubeTranscriptApi.fetch(video_id, languages=languages)
        
        # 3. 자막 목록의 'text' 부분을 하나의 문자열로 결합합니다.
        transcript_text = " ".join([entry["text"] for entry in transcript_list])
        return transcript_text

    except Exception as e:
        raise RuntimeError(f"비디오 ID '{video_id}'에 대한 자막을 찾을 수 없거나 사용할 수 없습니다.{e}")

# %%
transcript = get_youtube_transcript("https://www.youtube.com/watch?v=gYqs-wUKZsM") # operator 관련 영상  OpenAI
print(transcript) # "notebook.output.wordWrap": true in settings.json
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 13, in get_youtube_transcript(url)
#      12 try:
# ---> 13     transcript_list = YouTubeTranscriptApi.fetch(video_id, languages=languages)
#      15     # 3. 자막 목록의 'text' 부분을 하나의 문자열로 결합합니다.
#
# TypeError: YouTubeTranscriptApi.fetch() missing 1 required positional argument: 'video_id'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 transcript = get_youtube_transcript("https://www.youtube.com/watch?v=gYqs-wUKZsM") # operator 관련 영상  OpenAI
#       2 print(transcript) # "notebook.output.wordWrap": true in settings.json
#
# Cell In[8], line 20, in get_youtube_transcript(url)
#      17     return transcript_text
#      19 except Exception as e:
# ---> 20     raise RuntimeError(f"비디오 ID '{video_id}'에 대한 자막을 찾을 수 없거나 사용할 수 없습니다.{e}")
#
# RuntimeError: 비디오 ID 'gYqs-wUKZsM'에 대한 자막을 찾을 수 없거나 사용할 수 없습니다.YouTubeTranscriptApi.fetch() missing 1 required positional argument: 'video_id'
