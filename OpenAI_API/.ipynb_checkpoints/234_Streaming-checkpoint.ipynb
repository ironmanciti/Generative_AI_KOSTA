# %% [markdown]
# # 스트리밍 API 응답
# 기본적으로 OpenAI API에 요청을 보내면 모델의 전체 출력을 생성한 후 단일 HTTP 응답으로 다시 전송합니다. 긴 출력을 생성할 경우 응답을 기다리는 데 시간이 걸릴 수 있습니다.
# 스트리밍 응답을 사용하면 전체 응답을 생성하는 동안 모델 출력의 시작 부분을 인쇄하거나 처리할 수 있습니다.
#
# 응답 스트리밍을 시작하려면 `stream=True` 응답 엔드포인트에 대한 요청을 설정합니다.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI()

Model = "gpt-5-nano"

# %%
# 모델에게 요청을 보낼 때 stream=True 옵션을 사용하면
# 모델이 생성하는 텍스트를 토큰 단위로 실시간으로 받을 수 있습니다.
stream = client.responses.create(
    model=Model,  
    input=[
        {
            "role": "user",  
            "content": "Agentic AI 가 일반 AI 와 어떻게 다른지 자세히 설명해줘",  
        },
    ],
    stream=True,  # 스트리밍 모드 활성화
)

# 실시간으로 들어오는 모델의 출력(chunk)을 순차적으로 처리
for chunk in stream:
    # 'response.output_text.delta'는 모델이 생성 중인 텍스트 델타(부분 문자열)를 의미
    if chunk.type == 'response.output_text.delta':  
        print(chunk.delta, end="")   # chunk.delta : 새로 추가된 텍스트 조각
# Out:
# 다음은 Agentic AI(에이전트적 AI)와 일반적으로 말하는 Artificial General Intelligence(AGI, 인공 일반지능)의 차이를 자세히 설명한 내용입니다.
#
# 1) 정의 비교
# - Agentic AI(에이전트적 AI)
#   - 특정 목적(또는 목표)을 달성하기 위해 자율적으로 행동하는 시스템.
#   - 환경을 관찰하고, 목표를 설정하거나 추구하며, 계획을 세우고, 행동을 취한 뒤 결과를 학습합니다.
#   - 반드시 광범위한 지능을 갖는다는 뜻은 아니고, 한 가지 도메인에서의 자율성이나 목표 지향성을 강조합니다. 예를 들어 자율주행차, 주식 트레이딩 봇, 자동화된 물류 로봇 등이 해당합니다.
# - AGI(Artificial General Intelligence, 인공 일반지능)
#   - 인간 수준의 범용 지능을 갖추어, 거의 모든 지적 작업을 인간과 비슷한 수준으로 수행할 수 있는 시스템을 말합니다.
#   - 도메인에 구애받지 않고 학습, 추론, 문제 해결, 창의성 등을 다양한 영역에서 적용할 수 있는 능력을 목표로 합니다.
#   - 에이전트(행동 주도성) 여부와 상관없이 “모든 지적 작업을 폭넓게 다룰 수 있는 일반지능”을 뜻합니다.
#
# 2) 핵심 차이점 요약
# - 목표의 범위
#   - 에이전트적 AI: 특정 목표를 달성하기 위한 자율적 행동에 집중. 도메인은 협소하거나 좁을 수 있음.
#   - AGI: 도메인에 상관없이 폭넓은 지능을 발휘하는 일반화된 능력.
# - 행동의 주체성
#   - 에이전트적 AI: 환경에 대해 스스로 목표를 세우고 그 목표를 향해 행동하는 주체(에이전트)로 설계되는 경우가 많습니다.
#   - AGI: 지능적 문제 해결 능력 자체에 초점이 있으며, 반드시 외부 세계로의 적극적 행동(실행)을 포함하지 않을 수도 있습니다. 다만 실제 구현에서 에이전트 형태로 사용되기도 합니다.
# - 작동 방식의 초점
#   - 에이전트적 AI: perception(감지) → belief/목표 설정 → 계획/결정 → action(실행) → feedback 학습의 순환이 강조됩니다.
#   - AGI: 높은 범용성의 목표가 있으며, 학습과 추론 능력의 일반화가 핵심입니다. 여러 태스크를 빠르게 전이 학습하고 적응하는 능력이 중점입니다.
# - 현재 상태
#   - 에이전트적 AI: 이미 널리 사용 중인 사례가 많습니다. 예: 자율주행 차량, 로봇 팔의 자동 조작, 자동화된 트레이딩 시스템.
#   - AGI: 아직 실현되지 않은 목표로 남아 있습니다. 이론적으로는 가능성을 다루지만, 실용적인 시스템으로 상용화된 예는 없습니다.
#
# 3) 작동 원리와 구성 요소의 차이
# - 에이전트적 AI의 구성 요소
#   - 관측/감지: 센서 데이터, 피드백
#   - 목표 설정 또는 목적 함수: 무엇을 달성할지 정의
#   - 계획/의사결정: 목표 달성을 위한 전략 수립
#   - 행동: 물리적 또는 디지털 환경에의 실행
#   - 학습/적응: 실행 결과를 바탕으로 정책이나 모델을 개선
#   - 예: RL(강화학습) 기반 에이전트, 계획형 에이전트, 하이브리드(감지-계획-실행) 구조
# - AGI의 구성 방식
#   - 범용적 학습 능력: Few-shot/zero-shot 학습, 메타학습, 지식 전이, 추론 능력의 폭넓은 적용
#   - 다중 도메인 문제 해결 능력: 언어, 시각, 물리적 조작, 논리추론 등을 하나의 시스템이 통합적으로 다룰 수 있는 능력
#   - 에이전시 여부는 별개: AGI가 반드시 자율적 행동을 해야 하는 것은 아니며, 필요 시 에이전트로 작동하도록 설계될 수 있습니다.
#
# 4) 예시를 통한 비교
# - 에이전트적 AI 예시
#   - 자율주행차: 도로 상황을 인지하고, 목적지까지 안전하게 도달하기 위해 계획하고 실제 운전을 수행합니다.
#   - 로봇 팔의 자동 생산 라인: 주어진 생산 목표를 달성하기 위해 필요한 동작을 자율적으로 결정하고 수행합니다.
#   - 자율 트레이딩 봇: 시장 정보를 관찰하고, 목표 수익을 달성하기 위해 매매 결정을 내리고 실행합니다.
# - AGI를 지향하는 예시(이론적)
#   - 하나의 시스템이 언어 이해, 물리적 조작, 창의적 문제 해결, 과학적 추론 등 다양한 영역에서 인간과 비슷한 수준으로 수행할 수 있는 지능.
#   - 현실적으로는 아직 구현되지 않았고, 지금은 AGI에 근접하는 능력을 갖추려는 연구가_progress를 보이는 단계입니다.
#
# 5) 안전성과 윤리적 이슈
# - 에이전트적 AI의 안전 이슈
#   - 목표 누출, 보상 해킹, 악의적 목적에 의한 악용 가능성
#   - 도구로서의 활용성과 자율성 사이의 균형 필요
#   - 의도치 않은 행동(Instrumental goals: 예를 들어 자원 확보, 회피 회피 등) 가능성
# - AGI의 안전 이슈
#   - 가치 정렬(Alignment): 시스템의 목표가 인간의 가치와 충돌할 위험
#   - Corrigibility(교정 가능성): 잘못된 행동을 발견했을 때 시스템이 스스로를 수정할 수 있는가
#   - 오남용 위험: 강력한 범용 지능이 악용될 가능성
# - 공통
#   - 투명성, 해석가능성, 평가와 감독체계, 안전장치 및 거버넌스의 중요성
#
# 6) 평가 관점
# - 에이전트적 AI 평가
#   - 목표 달성도, 안전성, 로버스트성(환경 변화에 대한 견고함), 학습 속도, 해석가능성, 오작동 시 실패복구 능력
# - AGI 평가
#   - 범용성(다양한 도메인에서의 성능), 지식전이 능력, 학습 효율성(적은 데이터로도 빠른 적응), 창의성, 추론의 정확성, 안전성 및 시나리오 상호운용성
#
# 7) 실무적으로 구분하는 간단한 체크리스트
# - 시스템이 하는 일이 대부분의 환경에서 자율적으로 목표를 세우고 행동으로 옮기는가? → 에이전트적 AI 가능성 증가
# - 시스템이 한두 가지 도메인을 넘어 다양한 문제를 한 가지 학습 방식으로 처리할 수 있는가? → AGI 가능성 또는 AGI에 근접한 연구
# - 시스템의 주된 목적이 "무엇을 얻어내는가"보다는 "무엇을 이해하고 어떤 문제를 풀 수 있는가"에 더 가까운가? → AGI적 성향; 단, 에이전트로도 구현될 수 있음
# - 시스템의 주된 위험이 목표의 오염·보상 해킹 등 행동의 잘못된 방향으로의 최적화인가? → 안전/윤리 이슈 중요
#
# 원하시면 관심 분야(예: 로봇, 자율주행, 금융 트레이딩, 챗봇 등)나 특정 사례를 들어 더 자세히 비교해 드릴게요. 또한 에이전트적 AI와 AGI의 현재 연구 동향이나 안전 프레임워크에 관해 더 알고 싶으시면 그 부분도 정리해 드리겠습니다.
